# %%
import gensim
import pandas as pd

# %%
df=pd.read_csv("dataa.csv")

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df['Maker_Model'] = df['Make'] + " " + df['Model']

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP', 'Maker_Model'],
#       dtype='object')

# %%
df.Maker_Model
# Out:
# 0        BMW 1 Series M
# 1          BMW 1 Series
# 2          BMW 1 Series
# 3          BMW 1 Series
# 4          BMW 1 Series
#               ...
# 11909         Acura ZDX
# 11910         Acura ZDX
# 11911         Acura ZDX
# 11912         Acura ZDX
# 11913    Lincoln Zephyr
# Name: Maker_Model, Length: 11914, dtype: object

# %%
df1 = df[['Engine Fuel Type','Transmission Type','Driven_Wheels','Market Category','Vehicle Size', 'Vehicle Style', 'Maker_Model']]

# %%
df2=df1.apply(lambda x: ','.join(x.astype(str)),axis=1)

# %%
df1.head()
# Out:
#               Engine Fuel Type Transmission Type     Driven_Wheels  \
# 0  premium unleaded (required)            MANUAL  rear wheel drive
# 1  premium unleaded (required)            MANUAL  rear wheel drive
# 2  premium unleaded (required)            MANUAL  rear wheel drive
# 3  premium unleaded (required)            MANUAL  rear wheel drive
# 4  premium unleaded (required)            MANUAL  rear wheel drive
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#       Maker_Model
# 0  BMW 1 Series M
# 1    BMW 1 Series
# 2    BMW 1 Series
# 3    BMW 1 Series
# 4    BMW 1 Series

# %%
df2.head() #df2 is a series object and not a dataframe
# Out:
# 0    premium unleaded (required),MANUAL,rear wheel ...
# 1    premium unleaded (required),MANUAL,rear wheel ...
# 2    premium unleaded (required),MANUAL,rear wheel ...
# 3    premium unleaded (required),MANUAL,rear wheel ...
# 4    premium unleaded (required),MANUAL,rear wheel ...
# dtype: object

# %%
df_clean=pd.DataFrame({"clean":df2})

# %%
df_clean.head()
# Out:
#                                                clean
# 0  premium unleaded (required),MANUAL,rear wheel ...
# 1  premium unleaded (required),MANUAL,rear wheel ...
# 2  premium unleaded (required),MANUAL,rear wheel ...
# 3  premium unleaded (required),MANUAL,rear wheel ...
# 4  premium unleaded (required),MANUAL,rear wheel ...

# %%
sent = [row.split(',') for row in df_clean['clean']]

# %%
sent
# Out:
# [['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series M'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Audi 100'],
#  ['premium unleaded (recommended)',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'FIAT 124 Spider'],
#  ['premium unleaded (recommended)',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'FIAT 124 Spider'],
#  ['premium unleaded (recommended)',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'FIAT 124 Spider'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Mercedes-Benz 190-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Mercedes-Benz 190-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Mercedes-Benz 190-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Mercedes-Benz 190-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Mercedes-Benz 190-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Mercedes-Benz 190-Class'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 200'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Audi 200'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 200'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Audi 200'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Wagon',
#   'Audi 200'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 240'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Hybrid',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'BMW 3 Series'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Coupe',
#   'Mercedes-Benz 300-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Coupe',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Coupe',
#   'Mercedes-Benz 300-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Hatchback',
#   'Factory Tuner',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Hatchback',
#   'Factory Tuner',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Hatchback',
#   'Factory Tuner',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300M'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300M'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300M'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300M'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300M'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300M'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Hatchback',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mazda 323'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mazda 323'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mazda 323'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mazda 323'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mazda 323'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 350-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 350-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 350-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 350-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Performance',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Performance',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
# ...
#   'Saab 9000'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'Saab 9000'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Factory Tuner',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   '4dr Hatchback',
#   'Saab 9000'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'Saab 9000'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'Saab 9000'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'Saab 9000'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Porsche 928'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Porsche 928'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Porsche 928'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Midsize',
#   'Sedan',
#   'Mazda 929'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Midsize',
#   'Sedan',
#   'Mazda 929'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Midsize',
#   'Sedan',
#   'Mazda 929'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Porsche 944'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 944'],
#  ...]

# %%
from gensim.models.word2vec import Word2Vec

# %%
model=Word2Vec(sent, window=3, min_count=1,vector_size=50,workers=3,sg=1)

# %%
model.save("word2vec.model")

# %%
model = Word2Vec.load("word2vec.model")

# %%
model.wv['BMW 1 Series']
# Out:
# array([-5.30011989e-02,  3.57061252e-02,  1.10547401e-01, -1.26220062e-02,
#        -7.01672509e-02, -2.69249082e-01, -1.08637311e-01,  3.32464993e-01,
#        -2.79631056e-02, -1.52400792e-01,  1.32809430e-01,  1.53872706e-02,
#        -6.53810948e-02, -3.48905623e-02,  5.54177649e-02,  1.87218606e-01,
#         1.84143707e-01,  9.75061506e-02,  3.24765779e-02, -2.83052862e-01,
#        -5.00664897e-02,  4.05267812e-03,  2.22096145e-01, -4.02178541e-02,
#         1.93591312e-01,  4.67380770e-02, -2.21771091e-01,  3.36942703e-01,
#         8.29648376e-02, -1.50587291e-01, -1.37917042e-01,  9.98578668e-02,
#        -2.50575319e-02,  1.61923662e-01,  1.72519051e-02, -8.75819102e-02,
#         1.50409371e-01, -1.47021692e-02,  1.29918188e-01,  1.57201588e-01,
#         8.99950787e-02,  5.14309630e-02, -2.43880570e-01,  4.14645262e-02,
#         2.09192261e-01,  8.69234791e-05, -9.57554057e-02, -4.81383987e-02,
#         2.02887636e-02,  1.21496014e-01], dtype=float32)
